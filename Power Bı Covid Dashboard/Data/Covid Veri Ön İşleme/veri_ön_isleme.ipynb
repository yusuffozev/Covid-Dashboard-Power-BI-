# %%
import pandas as pd

# %%
data=pd.read_excel("Covid_Data _2.xlsx")
veri=data.copy()
veri.head()
# Out:
#    Unnamed: 0 Date_reported Country_code            Country WHO_region  \
# 0           0    2020-01-04           AF         Afganistan        EMR
# 1           1    2020-01-04           DZ          Cezayir\n        AFR
# 2           2    2020-01-04           AL         Arnavutluk        EUR
# 3           3    2020-01-04           AI         Anguılla\n        AMR
# 4           4    2020-01-04           AS  Amerika Samoası\n        WPR
#
#    New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# 0        NaN                 0         NaN                  0
# 1        NaN                 0         NaN                  0
# 2        NaN                 0         NaN                  0
# 3        NaN                 0         NaN                  0
# 4        0.0                 0         0.0                  0

# %%
veri.drop(columns=["Unnamed: 0","WHO_region","Cumulative_deaths"],inplace=True)
veri.head()
# Out:
#   Date_reported Country_code            Country  New_cases  Cumulative_cases  \
# 0    2020-01-04           AF         Afganistan        NaN                 0
# 1    2020-01-04           DZ          Cezayir\n        NaN                 0
# 2    2020-01-04           AL         Arnavutluk        NaN                 0
# 3    2020-01-04           AI         Anguılla\n        NaN                 0
# 4    2020-01-04           AS  Amerika Samoası\n        0.0                 0
#
#    New_deaths
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         0.0

# %%
veri.dropna(subset=["Country"],inplace=True)

# %%
veri.fillna(0,inplace=True)

# %%
veri.isnull().sum()
# Out:
# Date_reported       0
# Country_code        0
# Country             0
# New_cases           0
# Cumulative_cases    0
# New_deaths          0
# dtype: int64

# %%
veri.to_excel("Covid_Data _3 (Hazır Veri).xlsx")
